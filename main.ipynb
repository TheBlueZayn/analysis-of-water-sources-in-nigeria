# %% [markdown]
# # Analysis Of Source Of Drinking Water In Nigeria-2018

# %% [markdown]
# ## Analysis of Data
# - Import Libraries
# - Pandas for data analysis and wrangling
# - Matplotlib and Seaborn for Visualisation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data
# - Load CSV dataset into a DataFrame with Pandas

# %%
df = pd.read_csv("cfafrica-_-data-team-_-outbreak-_-covid19-_-openafrica-uploads-_-nigeria-source-of-drinking-wate.csv")

# %% [markdown]
# ## Explore Data
# - .head() to view the first five rows of dataframe
# - .info() to get insights on the entire dataset
# - .corr() to view the corellation between columns with numbers
# - Build a heatmap to better visualise the correlation matrix

# %%
df.head()
# Out:
#        Geography  Improved water source  Water piped into dwelling  \
# 0        Nigeria                   62.0                        1.9
# 1          Urban                   70.6                        3.6
# 2          Rural                   55.4                        0.6
# 3  North Central                   62.9                        1.5
# 4     North East                   53.6                        2.3
#
#    Water piped into yard/plot  Public tap/standpipe  Water piped to neighbor  \
# 0                         1.6                   7.5                      0.7
# 1                         2.2                   7.4                      1.1
# 2                         1.2                   7.5                      0.4
# 3                         1.4                   2.9                      0.4
# 4                         0.5                  12.0                      0.8
#
#    Tubewell/borehole  Protected well  Protected spring  Rainwater  \
# ...

# %%
print("The DataFrame Shape is", df.shape)
# Out:
# The DataFrame Shape is (46, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Geography                   46 non-null     object
#  1   Improved water source       46 non-null     float64
#  2   Water piped into dwelling   46 non-null     float64
#  3   Water piped into yard/plot  46 non-null     float64
#  4   Public tap/standpipe        46 non-null     float64
#  5   Water piped to neighbor     46 non-null     float64
#  6   Tubewell/borehole           46 non-null     float64
#  7   Protected well              46 non-null     float64
#  8   Protected spring            46 non-null     float64
#  9   Rainwater                   46 non-null     float64
#  10   Bottled water/demi john    46 non-null     float64
#  11  Unimproved water source     46 non-null     float64
#  12  Unprotected well water      46 non-null     float64
# ...

# %%
corr = df.corr()
corr
# Out:
#                             Improved water source  Water piped into dwelling  \
# Improved water source                    1.000000                  -0.061297
# Water piped into dwelling               -0.061297                   1.000000
# Water piped into yard/plot               0.132505                   0.065326
# Public tap/standpipe                    -0.089721                   0.281648
# Water piped to neighbor                 -0.048207                   0.189354
# Tubewell/borehole                        0.675896                  -0.109413
# Protected well                           0.171611                  -0.232362
# Protected spring                         0.375498                  -0.188359
# Rainwater                                0.101576                  -0.198965
#  Bottled water/demi john                 0.040519                   0.110621
# Unimproved water source                 -0.999504                   0.055657
# ...

# %%
sns.heatmap(corr, cmap="Blues")
plt.title("Correlation Matrix between the Sources of Drinking Water in Nigeria")
plt.savefig("corrmatrix", dpi=300, bbox_inches="tight"), ;

# %% [markdown]
# # Subset Data

# %% [markdown]
# ## Subset Data into Urban and Rural
# - Use pandas to subset
# - Visualize Subset with matplotlib barplot
# - Customize plot size, labels and title

# %%
urban_rural = df.loc[1:2, :]
urban_rural
# Out:
#   Geography  Improved water source  Water piped into dwelling  \
# 1     Urban                   70.6                        3.6
# 2     Rural                   55.4                        0.6
#
#    Water piped into yard/plot  Public tap/standpipe  Water piped to neighbor  \
# 1                         2.2                   7.4                      1.1
# 2                         1.2                   7.5                      0.4
#
#    Tubewell/borehole  Protected well  Protected spring  Rainwater  \
# 1               41.1            11.5               0.6        2.2
# 2               33.1            10.8               0.4        1.4
#
#     Bottled water/demi john  Unimproved water source  Unprotected well water  \
# 1                       0.9                     29.2                     4.4
# 2                       0.1                     44.6                    25.9
#
#    Unprotected spring  Tanker truck  Cart with tank  Sachet water  \
# ...

# %%
urban_rural.set_index("Geography").plot(kind="bar",
                                        figsize=(20,10)) 
plt.xlabel("Geographical Areas", fontdict={"fontsize":15})
plt.xticks(rotation=0, fontsize=15)
plt.ylabel("Count", fontdict={"fontsize":15})
plt.title("Sources of Drinking Water in Nigeria", fontdict={"fontsize":20})
plt.savefig('rural_urban.png', dpi=300, bbox_inches="tight")

# %% [markdown]
# ## Subset Into Geo-Political Zones
# - Use pandas to subset data
# - Visualise a scatterplot to show the relationship between improved water and water piped in

# %% [markdown]
# ## Subset Into Geo-Political Zones
# - Use pandas to subset data
# - Visualise a scatterplot to show the relationship between improved water and water piped in

# %%
geo_zones = df.loc[3:8, :]
geo_zones
# Out:
#        Geography  Improved water source  Water piped into dwelling  \
# 3  North Central                   62.9                        1.5
# 4     North East                   53.6                        2.3
# 5     North West                   55.5                        2.2
# 6     South East                   77.7                        0.7
# 7     South West                   65.9                        1.4
# 8    South South                   71.4                        2.9
#
#    Water piped into yard/plot  Public tap/standpipe  Water piped to neighbor  \
# 3                         1.4                   2.9                      0.4
# 4                         0.5                  12.0                      0.8
# 5                         3.2                   6.7                      1.0
# 6                         0.7                   2.8                      0.0
# 7                         0.5                   7.0                      0.4
# ...

# %%
sns.scatterplot(x="Improved water source", y="Water piped into dwelling", data=geo_zones, hue="Geography")
plt.title("Improved Water Source Against Water Pumped into Dwelling", fontdict={'fontsize':10, 'fontweight':20})
plt.savefig('relationships', dpi=300, bbox_inches='tight');

# %% [markdown]
# ## Subset Into States
# - Subset with pandas
# - Visualisea horizontal barplot of the best 15 states with improved water sources
# - Visualise a horizontal barplot of the worst 15 states with improved water sources
# - Visualise a barplot of the best state and worst state
# - Visuaiise the various water sources in Lagos State

# %%
states =  df.loc[9:].set_index("Geography")
states.shape
# Out:
# (37, 19)

# %%
states
# Out:
#              Improved water source  Water piped into dwelling  \
# Geography
# FCT Abuja                     57.8                       16.5
# Benue                         73.0                        0.0
# Kogi                          65.3                        0.2
# Kwara                         63.1                        1.9
# Nasarawa                      74.1                        1.0
# Niger                         60.6                        1.1
# Plateau                       44.7                        0.0
# Adamawa                       51.5                        0.2
# Bauchi                        58.1                        2.2
# Borno                         58.8                        4.5
# Gombe                         35.7                        1.4
# Taraba                        38.6                        0.5
# Yobe                          62.7                        3.0
# Jigawa                        82.2                        1.9
# ...

# %%
best_states = states["Improved water source"].sort_values(ascending=False)[:15].sort_values()

best_states.plot(kind="barh",color="purple")
plt.xlabel("Count")
plt.title("States in Nigeria with the Best Water Sources")
plt.savefig('beststates', dpi=300, bbox_inches='tight');

# %%
worst_states = states["Unimproved water source"].sort_values(ascending=False)[:15].sort_values()
worst_states.plot(kind="barh", color="#1fa6c4")
plt.xlabel("Count")
plt.title("States in Nigeria with the Worst Water Sources")
plt.savefig('worststates', dpi=300, bbox_inches='tight');

# %%
states["Improved water source"].max()
# Out:
# 89.5

# %%
states[states["Improved water source"] == 89.5]
# Out:
#            Improved water source  Water piped into dwelling  \
# Geography
# Abia                        89.5                        0.0
#
#            Water piped into yard/plot  Public tap/standpipe  \
# Geography
# Abia                              0.6                   0.0
#
#            Water piped to neighbor  Tubewell/borehole  Protected well  \
# Geography
# Abia                           0.0               83.1             0.0
#
#            Protected spring  Rainwater   Bottled water/demi john  \
# Geography
# Abia                    5.4        0.1                       0.4
#
#            Unimproved water source  Unprotected well water  \
# Geography
# Abia                          10.5                     0.0
#
#            Unprotected spring  Tanker truck  Cart with tank  Sachet water  \
# Geography
# Abia                      2.1           0.0             0.0           1.4
#
#            Unimproved bottled water  Surface water  Other water source
# Geography
# ...

# %%
highest_state = states.loc["Abia"]
highest_state.sort_values(ascending=False).sort_values().plot(kind="barh",
                                                                   color="purple",
                                                                   figsize=(10,10))
plt.xlabel("Count")
plt.ylabel("Water Source")
plt.title("Sources of Drinking Water in Abia State")
plt.savefig('higheststate', dpi=300, bbox_inches='tight');

# %%
states["Unimproved water source"] .max()
# Out:
# 64.3

# %%
states[states["Unimproved water source"] == 64.3]
# Out:
#            Improved water source  Water piped into dwelling  \
# Geography
# Gombe                       35.7                        1.4
#
#            Water piped into yard/plot  Public tap/standpipe  \
# Geography
# Gombe                             0.0                   0.6
#
#            Water piped to neighbor  Tubewell/borehole  Protected well  \
# Geography
# Gombe                          0.8               25.4             6.2
#
#            Protected spring  Rainwater   Bottled water/demi john  \
# Geography
# Gombe                   0.0        1.3                       0.0
#
#            Unimproved water source  Unprotected well water  \
# Geography
# Gombe                         64.3                    31.4
#
#            Unprotected spring  Tanker truck  Cart with tank  Sachet water  \
# Geography
# Gombe                     0.5           5.0             2.2           1.6
#
#            Unimproved bottled water  Surface water  Other water source
# Geography
# ...

# %%
lowest_state = states.loc["Gombe"]
lowest_state.sort_values(ascending=False).sort_values().plot(kind="barh",
                                                                   color="#1fa6c4",
                                                                   figsize=(10,10))
plt.xlabel("Count")
plt.ylabel("Water Source")
plt.title("Sources of Drinking Water in Gombe State")
plt.savefig('loweststate', dpi=300, bbox_inches='tight');

# %%
states.loc["Lagos"].sort_values(ascending=False).sort_values().plot(kind="barh",
                                                                   color="k",
                                                                   figsize=(10,10))
plt.xlabel("Count")
plt.ylabel("Water Source")
plt.title("Sources of Drinking Water in Lagos State")
plt.savefig("lagos", dpi=300, bbox_inches="tight");
